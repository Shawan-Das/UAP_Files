# %% [markdown]
# Lecture_03:
# https://colab.research.google.com/drive/1Ie2DxBUIZU-KSveLXnv1ZNerLx3qdrvQ?usp=sharing

# %% [markdown]
# Lecture_04:
# https://colab.research.google.com/drive/1_hH7zG2DRIlV7s14qeyxQCBnBHF87RIP?usp=sharing

# %% [markdown]
# Lecture_05:
# https://colab.research.google.com/drive/1AdG8vBzwxj-j-7KUYIvBbcriVQVgzKPz?usp=sharing

# %% [markdown]
# Lecture_06:
# https://colab.research.google.com/drive/1w792jggSfUm4jphiTyd2BL3DcxzUymW_?usp=sharing

# %% [markdown]
# Lecture_07: https://colab.research.google.com/drive/1T8HJWz713rqbJ8Fskg_DcuXp40rYDFZH?usp=sharing#scrollTo=U9otVodYwuMo

# %% [markdown]
# Lecture_08 : https://colab.research.google.com/drive/1CY-8yewwH4u1lkoSic2k3c4eZVwRrff1?usp=sharing&authuser=1
