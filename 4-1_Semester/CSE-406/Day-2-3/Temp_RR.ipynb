# %%
n= int(input("Total Number of Process: "))
q= int(input("Quantum Number: "))

# Arrival time / Burst Time
Arrrival_time=[]
Burst_time=[]
process=[]

for i in range(n):
  at, bt = input().split(" ")
  process.append(int(i))
  Arrival_time.append( int(at) )
  Burst_time.append( int (bt) )

Arrival_time,process,Burst_time=zip(*sorted(zip(Arrival_time,
                                                process,
                                                Burst_time)))

# temp Burst
temp_burst=Burst_time[]

#Complition Time
complition_time=[]

prev_comp=0

#first Served element:
if(temp_burst[0]>q):
  completion_time[0]= temp_burst[0]-q
  prev_comp=completion_time[0]
  temp_burst[0]-=q
else:
  completion_time[0]=temp_burst_time[0] 


i=1
while(max(temp_burst)>0):
  if(temp_burst[i]>q):
    extra= temp_burst[i] - q
  else:
    completion_time[i] += prev_comp
    prev_comp=completion_time[i]
    temp_burst[i]=0
